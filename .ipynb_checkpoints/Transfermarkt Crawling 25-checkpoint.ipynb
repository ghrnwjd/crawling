# %%
# 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# request.get() 으로 url 정보 요청하기
headers = { 'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36 "}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers= headers)
r.status_code
# Out:
# 200

# %%
#BeautifulSoup() 으로 웹페이지 분석 준비하기
soup = BeautifulSoup(r.text, 'html.parser') # r.text or r.content
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1659357244" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1659357259" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1659357259" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1659357252" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1659357252" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1659357252" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1659357251" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
# <link as="script" href="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" rel="preload"/>
# <script src="//data-84a0f3455d.transfermarkt.com/iomm/latest/bootstrap/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#             window.tmGaId = "UA-3816204-13";
#         </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 03093126 */ !function(i,e){function t(i,e){var t=pi(i);if(!t)return t;if(""!=e)for(var n=0;n<e.length;n++){var l=v(e,n);"^"==l&&(t=t.parentNode),"<"==l&&(t=t.previousElementSibling),">"==l&&(t=t.nextElementSibling),"y"==l&&(t=t.firstChild)}return t}function n(i,e){var t=li(e);return{x:i.clientX-t.left,y:i.clientY-t.top}}function l(i){for(var e=0,t=0;i;)e+=i.offsetLeft+i.clientLeft,t+=i.offsetTop+i.clientTop,i=i.offsetParent;return{x:e,y:t}}function s(i,e){var t=0,n=0,s=l(e);return(i.pageX||i.pageY)&&(t=i.pageX,n=i.pageY),(i.clientX||i.clientY)&&(t=i.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,n=i.clientY+document.body.scrollTop+document.documentElement.scrollTop),t-=s.x,n-=s.y,{x:t,y:n}}function r(i,e){return ni(e)?n(i,e):s(i,e)}function d(i,e){i.addEventListener?R(i,"click",e,!0):i.attachEvent&&i.attachEvent("onclick",function(){return e.call(i,window.event)})}function o(e,t){return i[w("c2V0VGltZW91dA==")](e,t)}function a(i){return parseInt(i.toString().split(".")[0],10)}function v(i,e){return i[e]}function u(){return Hi=(Ui*Hi+Si)%Oi}function p(){return u()/(Oi-1)}function f(){return p()}function z(i,e){return i>e?i:e}function h(){for(var i="",e=65;e<91;e++)i+=c(e);for(var e=97;e<123;e++)i+=c(e);return i}function c(i){return v(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+v("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",i-32)}function w(i){var e,t,n,l,s,r,d,o=h()+"0123456789+/=",a="",u=0;for(i=i.replace(/[^A-Za-z0-9\+\/\=]/g,"");u<i.length;)l=o.indexOf(v(i,u++)),s=o.indexOf(v(i,u++)),r=o.indexOf(v(i,u++)),d=o.indexOf(v(i,u++)),e=l<<2|s>>4,t=(15&s)<<4|r>>2,n=(3&r)<<6|d,a+=c(e),64!=r&&(a+=c(t)),64!=d&&(a+=c(n));return a}function m(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(i){return"unknown"}}function R(i,e,t,n){n=n||!1;try{i.addEventListener(e,t,n)}catch(n){i.attachEvent&&i.attachEvent("on"+e,t)}}function g(i){if(!i)return"";for(var e=w("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),t="",n=0;n<i.length;n++){t+=e.indexOf(i[n])>-1?w("XA==")+i[n]:i[n]}return t}function x(i){if(!i)return"";var e="";return i.id&&i.id.length>0&&(e+="#"+g(i.id)),i.className&&i.className.length>0&&(e+="."+g(i.className).split(" ").filter(function(i){return i&&i.length>0}).join(".")),e}function k(i){Pi[i]=!1}function j(i,e){var t=Li++;Pi[t]=!0;var n=function(e){return function(){i.call(null),Pi[t]&&o(n,e)}}(e);return o(n,e),t}function y(i){var e=!1;return Object.keys(i).forEach(function(t){e=e||i[t]}),!e}function b(i,e){return i&&(i.consents&&i.consents[e]||i.legitimateInterests&&i.legitimateInterests[e])}function q(e){return!!i.ivlzs7b2Flags.strictNCNA&&(b(e,2)&&b(e,7)&&b(e,9)&&b(e,10))}function E(i,e,t){var n=function(){return!!e()&&(t(),!0)};if(!n()){var l=j(function(){n()&&k(l)},250);n()}}function T(i){W(i)}function W(i){if(i.ivlzsbd4sdl&&!i.ivlzsce5Injct){i.ivlzsce5Injct=!0,i.ivlzs16fPc={},i.ivlzsd2eOc=[],i.ivlzsfb0Am={},i.ivlzs0f6Av={},i.ivlzs7ceAw={},i.ivlzs870Rqr={},i.ivlzsbe2Rqq=[],i.ivlzs0f6Avt={},i.ivlzs355Ev={};var t=[];if(!i.ivlzs7b2Flags.welect.eenabled||PHFSXWelect()){if(ivlzs7b2Flags.ptbd2ls){var n=ivlzs7b2Flags.baac3it,l=ivlzs7b2Flags.mb384el||10,s=ivlzs7b2Flags.ig943BP,r=function(){var i=D("style");i.type="text/css";var t=!1,n=D("style");n.type="text/css";var l=!1;return function(r,d){if(d)if("b"!==r||t){if("r"===r)if(l){var o=n,a=o.sheet;a.insertRule(d,0)}else l=!0,C(n,d),B(e.body,n)}else{if(t=!0,s)for(var v=0;v<s.length;v++)d=d.replace(new RegExp("([;{])"+s[v]+": [^;]+;","g"),"$1");var o="[^:;{",a="!important;";d=d.replace(new RegExp(o+"}]+: [^;]+\\s"+a,"g"),""),C(i,d),e.head.insertBefore(i,e.head.firstChild)}}}();if(n){if(n.length>l){for(var d=0,o=[0],v=[n[0]],u=1;u<l;u++){for(;o.indexOf(d)>-1;)d=a(f()*n.length);o.push(d),v[u]=n[d]}n=v,ivlzs7b2Flags.baac3it=v}for(var p={},z=0;z<n.length;z++){var h="string"==typeof n[z]?pi(n[z]):n[z];if(h&&h instanceof Node){var c={element:h,coe2eso:{},rc3cbcls:Vi(7),co3fbtx:""};if(c.co3fbtx+="."+c.rc3cbcls+"{",!s||s&&-1===s.in ...
# var d=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rYXWKzT7xw4t5s]rHjf}[866QUOWzYQru5ko{Jun<eP;2"+i.ivlzsda2Rnd+"YOZlg7lvGm\\T677{\\lhr6lZIug6Ht\\m5gnu7z9MjgJLJEz51jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2:J]vve]uLjZ;Kf<rqREoosXIP9HyPfQG}I5ROfVQX5k\\2"+i.ivlzsda2Rnd+"JKKQ\\ygvO[Ih6sfqmSuO6O;RP4yy49KTlvXVTE<57f]w8Hq1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rIG5J{\\V89VT\\wgW\\Kfmgvq}j:K89{EhgKyQmG6FxFTE2"+i.ivlzsda2Rnd+"LVZM85Lo53Sh7M97NTW9NgiOPLP]HOE8s{WTyNngjVQ4Gpp1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2J:[UwtwffQ}4<IEEkTOU84[8NirQ:LwvXlesyNfF4]lF2"+i.ivlzsda2Rnd+"\\TQxosIplNqKKQvFT4EI[{|W{w{oGpRpZ\\X9x|f}]\\vQH]m1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|YXf9IPNLF9hSq]TkVHw}]Nf]hzEgYSgoU:v5564h3\\L2"+i.ivlzsda2Rnd+"]LUp87Ox:GjQ;MQSOr<TyO[TH]OuEyst\\vOmZU:HX5zmw|M1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2;Gp9nKU8zUKsGl7K<RFun3S:RvZ;gjJuLTtS4nORjFxR2"+i.ivlzsda2Rnd+"UXNfEESGih;{i{oVoZ]7\\|7wEZ[mM]kYwpPO;t;XqpGTRUM1jli",-3)],o=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2vP:tpjUU;LKuRIJIs8Z}u96R8GyqKMtL]<|yxoKtoZYl2"+i.ivlzsda2Rnd+"RWUxo[ykoImpjQy3[\\OJFHvFOjFNrQf[|TzR66zYfTR[K6J1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2{UtkuQvOGsQuSp9w8k78Wg\\Xlr\\|UNX5m:{FUV[JZ|[{2"+i.ivlzsda2Rnd+"\\YGYK;OUToFysF:EVntjHVOy3W5ZPFZ]op58tnSqFf}nw7T1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2W4{Lj{75Ynly\\oUvt4j\\ukYrW76Ht\\SnEX3rP[GS\\HFp2"+i.ivlzsda2Rnd+"NG]v:G:w|\\jxmIZLl{;\\|M4}q8JXIJx{m8MxU{KeqeOZg4:1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2]VZjNL8S<Gxn6{h6x[M8]S:vSjeq3PjH7n;fQHf{mT]42"+i.ivlzsda2Rnd+"RX\\7nvOHW]nUZI;pXyrpNpFezfl]GRel7m3e]6SEJZ79M341jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2qzTns4Pmtj<XRhRI<jk4GKf|npQvkS6WF6H9XvMPilXm2"+i.ivlzsda2Rnd+"JETGg8z[9x65<{{vTwxg]qZeUh;}:sWkQHONe{xPfUOJmw51jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2ylUQ9\\[;56xgSgL|6;w|oQeqfR|S;4rGefn;VIsq3qLS2"+i.ivlzsda2Rnd+"SSFh4QO4|4tXqk{zFL\\4Q[nXPZP5wjqKYwlV{hn;skMxsT51jli",-3)],v=d[1*a(6*t.y/this.offsetHeight)+a(1*t.x/this.offsetWidth)],u=o[1*a(6*t.y/this.offsetHeight)+a(1*t.x/this.offsetWidth)];Ri(i,v,u,"_blank")}}),B(u,o),di(v,u),i.ivlzsd0214.a[9440]=u,M([{applyAdText:!0}],u,9440),Mi(u,9440,Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2V59n]j}nii3zSQEf[MZF]XNEnfNg;zkj4UT{U}JlRjTI2"+i.ivlzsda2Rnd+"OUZIMywzu9jTkPhJFwmEWHwu[}f<5;[F8in5UIpQKM{xGhl1jli",-3)),U(9440,t,!0)}}},function(){U(9440,t,!1)})}function p(e,t,l,s){l||zi(Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2lqQei;9}E}pr\\ZIsTrj7nSI]||W]3j6Y4VeNq:]HYyxE2"+i.ivlzsda2Rnd+"VZGowUIiyfPO3nu9v\\9wuhR6VYo<eUW\\\\o:XVG[yEwKp|I[1jli",-3),function(){if(!l){l=!0;var o=this;if(o.height<2)return void U(9931,t,!1);if(s==i.ivlzsda2Rnd){var v=e,u=D("div");n[""+w(Ti(w("V1o8bGRae29bMzRWUGpAQA=="),-3))]=u,ui(u,"uKELgkb");var p=o;i.ivlzsfb0Am[9931]&&(S(i.ivlzsfb0Am[9931]),i.ivlzsfb0Am[9931]=!1),d(p,function(e,t){if(!i.ivlzs16fPc[9931]){e.preventDefault(),e.stopPropagation();for(var t=r(e,this),n=0;n<i.ivlzsd2eOc.length;n++){var l=i.ivlzsd2eOc[n];if(9931==l.p&&t.x>=l.x&&t.x<l.x+l.w&&t.y>=l.y&&t.y<l.y+l.h){if(l.u){var s=l.t.length>0?l.t:"_self";s=0==e.button&&e.ctrlKey?"_blank":s,Ri(i,l.u,l.u,s,!0)}return}}var d=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2HmNoRxL{4YMfe8huZr4pw8po:Ws8zOt;m9xef\\wKWKG72"+i.ivlzsda2Rnd+"UG[TL9S}sZZp8ziM8V96qGxm|Yr7j}UKkxE3TgysTzN{|Kg1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh25RiJmI}qTgIuxTkJRZ9Q:P;4NY8tM<j}<tvGN4fNNj492"+i.ivlzsda2Rnd+"LYKOetY<9SNjyVi\\UG|pJokjljYs8JuSmvFxWs}zk|3SpPX1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh25RQIVNfU<RK\\4T\\[N4v5:X6l4G4Eqs{Us{6E\\x8{NEq92"+i.ivlzsda2Rnd+"LXT\\HomeTFUKqG<ry}PVmNVqPiKJp<YRT:HmNNJo6[k3mYm1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2f:3x5fTl<5HS96mYPSkv]xy<Zx}5gnL]NE5yqoJhZJ<\\2"+i.ivlzsda2Rnd+"Q]O6E:WRWZ3G|OVwGoPkSoVl983H]xjsVXlOVo\\I8snvTkp1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2E[4U8j{H3jORgpH]SytzlguNm8m4yN5{tW5Y[9{Lv]gx2"+i.ivlzsda2Rnd+"]YGr]q}iJPJm\\[sPm9RqlJz83R5{psV[\\s7<5<Fy7ut{3]o1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh27ljwT\\}8eXXUhoeZzZlvuT[ ...
# var d=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2UVP9nJkogop:8Q|U4g5]yNiLf3jRpOhplFSUK]g5:]oK2"+i.ivlzsda2Rnd+"OXYhpVF8ut[Vy5OPmUkko{JkvuP79n]4QXizWhIu<PsfM}e1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2RFq:SqtU5hmwfFWPkV95QGgZLskp3wXUvYmUHqkQL:]W2"+i.ivlzsda2Rnd+"TGSSYv9rwXxFl}Mtn:5k[XGq9pmrHo7Zpen8QWr[pKfEhqv1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2n:Gm|8J;F:NxU[<Lh6S3f]p9HzFXH9{Fp}N7G9p\\h5m;2"+i.ivlzsda2Rnd+"VOJmn7xpfQSZHt7mi<|l[TJ]<q\\|MtNr[r3L[fNLkuxJflL1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2X}6EkFKqhRFnY|38Zg8jyI{PQNSKIJjKhXrJrOyv[[lh2"+i.ivlzsda2Rnd+"PMZFKmElSOh]yp|gq[J3wtnZ:FF|lR:NmIow]<Yt7P[My6l1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2e]lWX4Ks6sTkwfyqrNqM45ty8EYmw7lP;\\HJPIN|g<Gg2"+i.ivlzsda2Rnd+"VMJg59]oUSF[YY\\WsMxNW{:}fE;lxVOV:RuI4<p\\|TF|KrJ1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2jEoHLKxVs}XV|[JLQuVwT]KOjoGUWlkqqpwyk;5yqqf;2"+i.ivlzsda2Rnd+"Z\\XYMifI]M|G5:Ig97:rNoVHfpE3yLq}WK{QF;L7m:|EVY\\1jli",-3)],o=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2pmh5hXHOFQMMW4EY;J7WN3J|wUkRRvneQIlrYq3SHzgJ2"+i.ivlzsda2Rnd+"RF\\:SZtWxzMTeh|z\\<8[WJ]}lRpYpg:M9J7jFKZNFKYJTgs1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2z}{xwGmf3xFQGOXnkX[PrKSF]:n9:RoVuQznLZoLxMlI2"+i.ivlzsda2Rnd+"TOMnXSRs583rIyp<k9[vEJm3xtzh7KL6;VgtkUsviipqw7}1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2NuOM3xIlvtGjfpY<QkEuHOERig7UHGXy{gg9PS5sz<682"+i.ivlzsda2Rnd+"VKFXowL}k|QQ6Q:{fGlw95N}<}|4}iTYmR{]iIU}Wl]Uin<1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2vuKV]s;eNERWjMqlw}RyZ\\ZGp8O8eW5\\vs;ro9TxiHhp2"+i.ivlzsda2Rnd+"\\LO5ueii9K[ikskerqzSFHnywHhHH9QvV\\5IevG5moWsyh61jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2uvJp7N]qZ6jr{[h4Ree\\6957YSMS9ET8:sgksK\\7[k4<2"+i.ivlzsda2Rnd+"RXGf;sqol5kW|Ynpm7rxgO[5GZ5k}UrMHVpJ]xn<s{E4XPH1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh26goHY5r3hu6qVf9ohQXkk}sT}mZF;P[I9Q7JPKGe6NgL2"+i.ivlzsda2Rnd+"IHK967mSER7g\\9ZYKX{w;xh75h8We|v\\w}<g3KWgYG[hMfK1jli",-3)],v=d[1*a(6*t.y/this.offsetHeight)+a(1*t.x/this.offsetWidth)],u=o[1*a(6*t.y/this.offsetHeight)+a(1*t.x/this.offsetWidth)];Ri(i,v,u,"_blank")}}),B(u,o),B(v,u);var f=i.ivlzsd0214.a[8695];f&&f.parentNode.removeChild(f),i.ivlzsd0214.a[8705]=u,Mi(u,8705,Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh28t9epQ]94qH8OgUPxX}]u5ONVNnoqM<5IXoVQwTor{rf2"+i.ivlzsda2Rnd+"REFv{y[Xw[Y3qXT{<qQJPTk5jJzYl8eiJ9v[::]7PWY85<81jli",-3)),U(8705,t,!0)}}},function(){U(8705,t,!1)})}function W(e,n,l){var s=t(""+w(Ti(w("TDZRcGdKTHs="),-3)),"");s?n(s,!e,!1,i.ivlzsda2Rnd):l(8939,!e,!1)}function V(e,t,l,s){l||zi(Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Tuk<oMukMKuelGLlzG{|pvEfYwJLg]8}xjGyNRTVmkYq2"+i.ivlzsda2Rnd+"KQOzhYLJ<WUWV\\xU7SZOO[9pr]Sk}jm|j\\vjh\\PV{sqhREV1jli",-3),function(){if(!l){l=!0;var o=this;if(o.height<2)return void U(8939,t,!1);if(s==i.ivlzsda2Rnd){var v=e,u=D("div");n[""+w(Ti(w("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Id1FUQEA="),-3))]=u,vi(u,"LdOmvY ");var p=o;i.ivlzsfb0Am[8939]&&(S(i.ivlzsfb0Am[8939]),i.ivlzsfb0Am[8939]=!1),d(p,function(e,t){if(!i.ivlzs16fPc[8939]){e.preventDefault(),e.stopPropagation();for(var t=r(e,this),n=0;n<i.ivlzsd2eOc.length;n++){var l=i.ivlzsd2eOc[n];if(8939==l.p&&t.x>=l.x&&t.x<l.x+l.w&&t.y>=l.y&&t.y<l.y+l.h){if(l.u){var s=l.t.length>0?l.t:"_self";s=0==e.button&&e.ctrlKey?"_blank":s,Ri(i,l.u,l.u,s,!0)}return}}var d=[Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rYw]R4KFMM;Htsvs3Lv]fPiOiwlZx7iOOQi9PTrUTyvY2"+i.ivlzsda2Rnd+"LIZo4xp<tv[VmyX}\\\\mIxpS]pSe{}tf7wplwYRNJ\\oHNI5<1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2fYxw5oTQL6wMjqL{lNGiLMuVON9P8:]wm}7R[PIPj7vT2"+i.ivlzsda2Rnd+"NKLzoqz:pZj7:iwNJyXTS3XwXeF[OHRHI|U3lTt9nZj\\6w[1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2z5[SXwR{f3g;9]yWwlm{}}J|8k;ikemeYsVFPIyZ3oh]2"+i.ivlzsda2Rnd+"UQVXImLo]zFF3vGeY7gwf9xwM]yo8YPR;[hxuvs8w7uVrxx1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2UzSg5O46F|eK5OhJZ4Yj8n\\ZNotG8Y9JgqKt]L6uevJS2"+i.ivlzsda2Rnd+"WV]Hp9<YuL|K{eHMKeX{nH|pNY{of8pk\\NTXgKh]zeZYto;1jli",-3),Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh28|E{qihweRKo9u<spTfYs\\v8p{SPqqgN|lillKj{WG6o2"+ ...
# ;e[w("YWRmX2lnbm9yZQ==")]="DU",e.responseType="text",e.open("GET",Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2MpN844muxYfs]Ns7MhnzT<HVV7X9uu8NkUyGy:m9w8hh2"+i.ivlzsda2Rnd+"[STQv9p9g4MixWgiFGM}Q9z};HlS[EMh\\fegZrFv}FTQiFN1jli",-3),!0),e.setRequestHeader("Content-Type","text/plain"),e.onreadystatechange=function(){if(4===e.readyState&&200===e.status){var t=w(Ti(e.response,-3)),n=JSON.parse(t);JSON.stringify(n);i.ivlzsd021o2=n.css,i.ivlzsd021o3=n.generic,i.ivlzsd021o3a=n.altGeneric,i.ivlzsd021o1=n.url,i.ivlzsd021o1a=n.altUrl,J()}},e.send()}else qi(this),J()};i.ivlzsb6dMobile?zi(Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yuiSEMm<4PxFeE4YT:3{[ZjLUsJ8vl\\JQhGgVGX9z]GI2"+i.ivlzsda2Rnd+"HMIlo[pwLJ[mTZhRJm5vLw9ne:OQh}h6{z}YxL]6S|YIrxk1jli",-3),n,n):zi(Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2I3|mNSvWiw|MhiZgPqjKgo]thwHpeH:Pe9ONU{Hr}JoR2"+i.ivlzsda2Rnd+"FS]nQkRxFUG:Xo;vmE9xKSQw;4gHYw;qQgrxYP:RoSTGJh]1jli",-3),n,n)}}function J(){var e=[],t=[];if(e.push({b6f6cs:".sponsor-ad",bueedrl:Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2q9rOZ[7Q9\\qFHq6ufm54YOOTHj:SqjeK9nnTOjmwuPIs2"+i.ivlzsda2Rnd+"RPI<|utHQ\\v4jQnstsjeTeMKz;s6k<46TxK;ps\\7f7qJH7v1jli",-3)}),t.push({b6f6cs:".sponsor-ad",bueedrl:Ti("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2dghqjdjh2knUP7wsxgglnw;H3iN\\Qv7Xw}Rs8nIte;sVKZeUFwpmM2"+i.ivlzsda2Rnd+"VIOWz|Mi|9s3VwGKfMHp<:[l85]|:;<Jp:t9jETuFj857|m1jli",-3)}),i.ivlzsd021o3.length>0){e=[];for(var n=0;n<i.ivlzsd021o3.length;n++)e.push({b6f6cs:ivlzsd021o3[n].bc,bueedrl:ivlzsd021o3[n].bu})}if(i.ivlzsd021o3a.length>0){t=[];for(var n=0;n<i.ivlzsd021o3.length;n++)t.push({b6f6cs:ivlzsd021o3a[n].bc,bueedrl:ivlzsd021o3a[n].bu})}!function(e,t){if(0!=e.length){var n=D("DIV");C(n,"&nbsp;"),B(Ki,n);for(var l=0,s=0;s<e.length;s++){var r=[],d=[],o=0,a=function(){o++,o===r.length&&((!i.ivlzs7b2Flags.gnrcfll&&d.length>0||d.length===o)&&(i.ivlzsd021tc.gn=!0),l++),l==e.length&&(oi(n),i.ivlzsd021tc.gnd=!0,Q())},v=gi(Ki,e[s].b6f6cs);r.push(xi(n,v.b,v.p,a,d));var u=e[s].bueedrl,p=t[s].bueedrl;r.push(function(){zi(u,ki(d,a,p),ki(d,a,p))});for(var f=0;f<r.length;f++)r[f]()}}}(e,t);for(var l=0;l<i.ivlzsd0211.length;l++)i.ivlzsd0211[l]();0==i.ivlzsd0211.length&&(i.ivlzsd021tc.abd=!0,Q()),(i.ivlzsfp||i.ivlzs7b2Flags.fp)&&H(!0,!1),i.ivlzs7b2Flags.fnc&&H(!1,!1),i.ivlzs7b2Flags.fab&&H(!1,!0)}function K(){if(i.ivlzsda2Rnd=i.ivlzsda2Rnd||A(),i.ivlzsbd4sdl&&!i.ivlzsbd4sdln&&(L(4),i.ivlzsbd4sdln=!0),!i.ivlzsbd4sdl){i.ivlzsbd4sdl=!0,i.ivlzsbd4sdln=!0,i.ivlzsd021genat="03093126",i.ivlzsd021sthash="89eed",i.ivlzsd021Domain=Ti("wudqvihupdunw1frp",-3),i.ivlzsda2Rnd=i.ivlzsda2Rnd||A(),i.ivlzsa3aforceimp=!1,i.ivlzs7b2Flags.newSafDet=!!i.ivlzs7b2Flags.newSafDet&&i.ivlzs7b2Flags.newSafDet,i.ivlzs7b2Flags.nwlforce=!!i.ivlzs7b2Flags.nwlforce&&i.ivlzs7b2Flags.nwlforce,i.ivlzs7b2Flags.gnrcfll=void 0===i.ivlzs7b2Flags.gnrcfll||i.ivlzs7b2Flags.gnrcfll,i.ivlzs7b2Flags.forceImp=!!i.ivlzs7b2Flags.forceImp&&i.ivlzs7b2Flags.forceImp,i.ivlzs7b2Flags.autoRecov=!!i.ivlzs7b2Flags.autoRecov&&i.ivlzs7b2Flags.autoRecov,i.ivlzs7b2Flags.fp=!!i.ivlzs7b2Flags.fp&&i.ivlzs7b2Flags.fp,i.ivlzs7b2Flags.npm=!!i.ivlzs7b2Flags.npm&&i.ivlzs7b2Flags.npm,i.ivlzs7b2Flags.rsp=void 0===i.ivlzs7b2Flags.rsp||i.ivlzs7b2Flags.rsp,i.ivlzs7b2Flags.nw388lst=!!i.ivlzs7b2Flags.nw388lst&&i.ivlzs7b2Flags.nw388lst,i.ivlzs7b2Flags.bl710Up=!!i.ivlzs7b2Flags.bl710Up&&i.ivlzs7b2Flags.bl710Up,i.ivlzs7b2Flags.pmasync=!!i.ivlzs7b2Flags.pmasync&&i.ivlzs7b2Flags.pmasync,i.ivlzssc={},i.ivlzssc.tsm={};var e=!1,t=j(function(){if(e=!0,null!=(Ki=pi("body"))){if(i.ivlzscf1Body)return;i.ivlzscf1Body=!0,k(t);var n=D("style");n.type="text/css",B(Ji,n),I()}},10),n=j(function(){k(n),e||L(4)},100)}}function A(){return Ti(_(),3)}function _(){for(var i="MghCoELFeYBOVWtz6Gi1wDQlbKf2ZJyUXPq9kHurjRcNTspdvImSn8x37504",e=z(10,1+a(10*f())),t="";t.length<e&&i.length>0;)t+=v(i,a(f()*i.length));return t}function D(i){return e.createElement(i)}function C(i,e){i.innerHTML=e}function B(i,e){i.appendChild(e)}function $(i,e,t){i[w("c2V0QXR0cmlidXRl")](e,t)}function ii(i,e){re ...
# }(l.open),function(e){i.ivlzs7b2Flags&&i.ivlzs7b2Flags.fetchRecoveryOff||(l.fetch=function(){var i=arguments;try{return!i[0]||"string"!=typeof i[0]||/^\/[^\/]/.test(i[0])||t(n(i[0]),Fi)||!I()||/(adnxs.com.+\/prebid)/.test(i[0])&&(!i[1]||!i[1].method||/(.*)/.test(i[1].method))||/(doubleclick.net.+&output=ldjh)/.test(i[0])&&(!i[1]||!i[1].method||/(.*)/.test(i[1].method))||/(adnxs.com.+v3$)/.test(i[0])&&(!i[1]||!i[1].method||/(POST)/.test(i[1].method))?e.apply(l,i):new Promise(function(t,n){e.apply(l,i).then(function(i){t(i)}).catch(function(s){function r(i){d||o||(n(i),o=!0)}var d=!1,o=!1;try{var a=i[0],v=p().test(a),u=Ii.consentString,f=Ii.gdprApplies;v&&(ki=!0),Ri.currentCount++,H({rewrittenUrlType:"failedRequest",type:"xhr",src:a,referer:zi,href:zi,isAdTag:v,consentString:u,gdprApplies:f},function(n){if(!n.rewrittenUrl)return void r(s);v&&Q(),i[0]=n.rewrittenUrl,e.apply(l,i).then(function(i){d=!0,t(i)}).catch(function(i){r(i)})},function(){r(s)})}catch(i){r(s)}})})}catch(t){return e.apply(l,i)}})}(l.fetch),function(i,t){i&&(e.body.appendChild=function(){var e=i.apply(this,arguments);try{var t=arguments[0],n=t&&t.nodeName&&t.nodeName.toLowerCase();if(X(t,n,t.src||t.href,this)&&I())switch(n){case"iframe":ni(t);break;case"script":O(t)}}catch(i){}return e}),l.Node.prototype.appendChild=function(){var i=t.apply(this,arguments);try{var e=arguments[0],n=e&&e.nodeName&&e.nodeName.toLowerCase();if(X(e,n,e.src||e.href,this)&&I())switch(n){case"iframe":ni(e);break;case"a":c(e);break;case"script":O(e)}}catch(i){}return i}}(e.body&&e.body.appendChild,l.Node.prototype.appendChild),function(i){l.Node.prototype.replaceChild=function(){var e=i.apply(this,arguments);try{var t=arguments[0]instanceof l.Element&&arguments[0].querySelector("IFRAME");t&&X(t,"iframe",t.src,this)&&I()&&(/Firefox/.test(l.navigator.userAgent)?R(t,"load",li,!0):ni(t))}catch(i){}return e}}(l.Node.prototype.replaceChild),O(e),function(i){e.createElement=function(){var t=i.apply(e,arguments);try{if(!I())return t;var n=arguments[0]&&arguments[0].toLowerCase();switch(n){case"iframe":R(t,"load",ti,!0);break;case"video":!function(i){t.appendChild=function(){try{var e=arguments[0].localName;if(!X(t,n,t.src))return i.apply(t,arguments);if("source"!==e)return i.apply(t,arguments);if(arguments[0].src&&!t.src)return t.src=arguments[0].src,null}catch(i){}}}(t.appendChild),R(t,"error",C,!0),R(t,"canplay",C,!0);break;case"img":t.orgnl_script=e.currentScript;case"div":case"script":O(t)}}catch(i){}return t}}(e.createElement)}}if(!(i[Ti("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]||i.location.search.indexOf("forceVideoOff=true")>-1)){i[Ti("ylghrVfulswLvDouhdg|H{hfxwhg",-3)]=!0,Array.isArray||(Array.isArray=function(i){return"[object Array]"===Object.prototype.toString.call(i)});var ri,di,vi,ui,fi,zi,hi,ci,wi,mi,Ri,gi,xi,ki,ji,bi,qi,Ei,Wi,Vi,Zi="qHIXrMdDLH",Fi=["transfermarkt.com","emsservice","adalliance","yahoo","jwplayer","ligatus","kameleoon","facebook","native.adscale.de","justpremium","twitter.com","consensu","meetrics","daznplayer","api.rlcdn.com","publisher-assets.spot.im","doubleclick.net/pagead/ppub_config","mdsngpush"],Gi=["t.vi-serve.com/\\?event","servt.vid-play.com/track","pixel.inforsea.com/server/log","prd.jwpltx.com","/gen_204","pp.lp4.io","meetrics.net/data","k.streamrail.com/x","m6r.eu/video/empty","brid.tv/ping.gif"],Mi="",Ni=Ti("kwwsv=22ylgdsl41wkuhhsl1gh2lpdjh2muyLeGXjm{4tZRK77fvxFvFUl\\sQoZ5Vv;48\\lr3gLu82RYKil4K<s7isLm4QniKxFNF;;|qIqXTFZ|vZpujX7PqNhln1jli",-3),Xi=Ti("kwwsv=22ylgdsl41wkuhhsl1gh2lpdjh2jsxyjof:Ln][EKr|serZwiNlnlq47I7MM39xfkYygIPp2ET\\iwmFKwLJ:uT5Le}o\\s[Ors}pvvXYg<rzn;Y;qfvkeGvz1jli",-3),Oi=[".ad-element"],Ui="#content_video_ima-ad-container, .fp-engine",Si=[".dianomi-video-background",".GUI-module__container__thumbnail"],Hi="video",Li="testIframe",Pi=m(),Qi=new RegExp("googlebot/|Googlebot-Mobile|Googlebot-Image|Google favicon|Mediapartners-Google|bingbot|slurp|java|wget|curl|Commons-HttpClient|Python-urllib|libwww|httpunit|nutch|phpcrawl|msnbot|jyxobot|FAST- ...
# </script>
# <div class="werbung werbung-header"><!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                           window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#                         </script>
# <!-- End GPT Tag --></div> </link></link></head>
# <body class="" data-cmp-layer-id="225676" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><!-- /58778164/Desktop-Skyscraper-1 -->
# <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#                           </script>
# </div></div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><!-- /58778164/Desktop-Skyscraper-2 -->
# <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#                           </script>
# </div></div> </div>
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://www.tiktok.com/@transfermarkt" onclick="tmEvent('SM-Icons_Header','click','Tiktok');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/tiktok.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </div>
# <nav class="main-navbar navihalter">
# <ul class="main-navbar__container megamenu_dark_bar megamenu_dark" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <li class="main-navbar__list" data-nav-group="news">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="transfers">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list aktiv" data-nav-group="marktwerte">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="wettbewerbe">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="foren">
# <a class="main-navbar__list-title tm-main-nav-el" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#             Forums                    </a>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="meintm">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#             My TM        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list">
# <a class="main-navbar__list-title tm-main-nav-el live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">
#             Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </li></li></li></li></li></li></ul>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy">
# <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z"></path>
# </g>
# </svg>
# </a>
# <div class="tm-login" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z"></path>
# </g>
# </svg>
# <span class="tm-login__cta">
#         Log in    </span>
# </div>
# </nav>
# <div class="quick-select-wrapper">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# <div class="werbung werbung-billboard"><!-- /58778164/Desktop-Billboard-1 -->
# <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#                           </script>
# </div></div> </header>
# <main>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <h2 class="content-box-headline">
#                 Most valuable players            </h2>
# <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Year:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="jahrgang" tabindex="0">
# <option value="0">All</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# ...
# <table>
# <thead>
# <tr>
# <th>player</th>
# <th class="zentriert" colspan="3">Transfer</th>
# <th class="rechts">Fee</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Gabriel Slonina" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/656316-1645958054.jpg?lm=1" title="Gabriel Slonina"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/gabriel-slonina/profil/spieler/656316" title="Gabriel Slonina">Gabriel Slonina</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/fc-chelsea/transfers/verein/631" title="Chelsea FC"><img alt="Chelsea FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/631.png?lm=1628160548" title="Chelsea FC"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/gabriel-slonina/transfers/spieler/656316/transfer_id/3988119?from=neustetransfersbox" title="Gabriel Slonina">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/chicago-fire-fc/transfers/verein/432" title="Chicago Fire FC"><img alt="Chicago Fire FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/432.png?lm=1634667489" title="Chicago Fire FC"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/gabriel-slonina/transfers/spieler/656316/transfer_id/3988119?from=neustetransfersbox" title="Gabriel Slonina">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         loan transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Renan" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/662325-1571841193.png?lm=1" title="Renan"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/renan/profil/spieler/662325" title="Renan">Renan</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/se-palmeiras-sao-paulo/transfers/verein/1023" title="Sociedade Esportiva Palmeiras"><img alt="Sociedade Esportiva Palmeiras" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1023.png?lm=1411204983" title="Sociedade Esportiva Palmeiras"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/renan/transfers/spieler/662325/transfer_id/3988427?from=neustetransfersbox" title="Renan">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/renan/transfers/spieler/662325/transfer_id/3988427?from=neustetransfersbox" title="Renan">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Bernd Leno" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/72476-1642711733.jpg?lm=1" title="Bernd Leno"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/bernd-leno/profil/spieler/72476" title="Bernd Leno">Bernd Leno</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Goalkeeper                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/fc-arsenal/transfers/verein/11" title="Arsenal FC"><img alt="Arsenal FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/11.png?lm=1489787850" title="Arsenal FC"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/bernd-leno/transfers/spieler/72476/transfer_id/3988240?from=neustetransfersbox" title="Bernd Leno">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/fc-fulham/transfers/verein/931" title="Fulham FC"><img alt="Fulham FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/931.png?lm=1556831687" title="Fulham FC"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/bernd-leno/transfers/spieler/72476/transfer_id/3988240?from=neustetransfersbox" title="Bernd Leno">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         €3.60m                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2025                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Jacob Shaffelburg" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/637632-1645891252.jpg?lm=1" title="Jacob Shaffelburg"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/jacob-shaffelburg/profil/spieler/637632" title="Jacob Shaffelburg">J. Shaffelburg</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/toronto-fc/transfers/verein/11141" title="Toronto FC"><img alt="Toronto FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/11141.png?lm=1410196948" title="Toronto FC"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/jacob-shaffelburg/transfers/spieler/637632/transfer_id/3988208?from=neustetransfersbox" title="Jacob Shaffelburg">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/nashville-sc/transfers/verein/63966" title="Nashville SC"><img alt="Nashville SC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/63966.png?lm=1550768787" title="Nashville SC"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/jacob-shaffelburg/transfers/spieler/637632/transfer_id/3988208?from=neustetransfersbox" title="Jacob Shaffelburg">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         Loan fee:<br/><i class="normaler-text">€205Th.</i> </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Andrea Schenetti" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/130357-1635893730.jpg?lm=1" title="Andrea Schenetti"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/andrea-schenetti/profil/spieler/130357" title="Andrea Schenetti">A. Schenetti</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/virtus-entella/transfers/verein/20519" title="Virtus Entella"><img alt="Virtus Entella" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/20519.png?lm=1424769530" title="Virtus Entella"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/andrea-schenetti/transfers/spieler/130357/transfer_id/3988205?from=neustetransfersbox" title="Andrea Schenetti">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/calcio-foggia-1920/transfers/verein/704" title="Calcio Foggia 1920"><img alt="Calcio Foggia 1920" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/704.png?lm=1656022770" title="Calcio Foggia 1920"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/andrea-schenetti/transfers/spieler/130357/transfer_id/3988205?from=neustetransfersbox" title="Andrea Schenetti">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><!-- /58778164/Desktop-MediumRectangle-2 -->
# <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#                           </script>
# </div></div> </div>
# </div>
# </main>
# <footer>
# <tm-language-hint></tm-language-hint>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           general terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM Team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# </footer>
# <div id="menue_overlay"></div>
# </div>
# <script type="text/javascript">
#                 var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#             </script>
# <script type="module">
#                 var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};
#             </script>
# <script type="text/javascript">
#                 if(typeof IOMm === 'function') {
#                     IOMm('configure', { st: iam_data.st, dn: 'data-84a0f3455d.transfermarkt.com', mh:5 });
#                     IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#                 } else {
#                     console.warn('IOMm is not defined');
#                 }
#             </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script defer="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js"></script> <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1659357252" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1659357251" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/vendors.min.js?lm=1659357251" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '1183159';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
# 선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr', class_ = ['odd', 'even'])
player_info[0]

# 전체 갯수 확인
print(len(player_info))
# Out:
# 25

# %%
# 7개의 정보를 담을 빈 리스트
# number, name, position, age, nation, team, value
number = []
name = []
position = []
age = []
nation = []
team = []
value = []

# %%
#player_info 에서 'td' 태그만 찾기
for info in player_info:
    player = info.find_all('td')
    #print(player)
    
# 해당 정보를 리스트에 추가
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5])
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())
